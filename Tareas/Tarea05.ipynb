# %% [markdown]
# # Tipografía matemática
# ### El objetivo de esta actividad es que cada estudiante alcance proficiencia en la redacción de expresiones matemáticas.
# ## Actividades
# ### Investigar sobre los atajos de teclado para ingresar ecuaciones matemáticas en Word y Latex.
# ### Realizar una tabla incluyendo al menos 30 símbolos.

# %% [markdown]
# ### Atajos de teclado Word
# | Acción            | Atajo                  | Ejemplo de uso               |
# | :---------------- | :--------------------- | :--------------------------- |
# | Insertar ecuación | `Alt` + `=`            | Abre el editor de ecuaciones |
# | Fracción          | `Ctrl` + `/`           | `1/2` → ½                    |
# | Potencia          | `^`                    | `x^2` → 𝑥²                  |
# | Subíndice         | `_`                    | `x_1` → 𝑥₁                  |
# | Raíz cuadrada     | `\sqrt` + `Espacio`    | `\sqrt(x)` → √𝑥             |
# | Pi                | `\pi` + `Espacio`      | → π                          |
# | Suma              | `\sum` + `Espacio`     | → ∑                          |
# | Integral          | `\int` + `Espacio`     | → ∫                          |
# | Infinito          | `\infty` + `Espacio`   | → ∞                          |
# | Theta             | `\theta` + `Espacio`   | → θ                          |
# | Aproximado        | `\approx` + `Espacio`  | → ≈                          |
# | Diferencial       | `\partial` + `Espacio` | → ∂                          |

# %% [markdown]
# ### Atajos de teclado en Latex
# | Acción           | Código           | Resultado          |
# | :--------------- | :--------------- | :----------------- |
# | Fracción         | `\frac{a}{b}`    | $\frac{a}{b}$   |
# | Potencia         | `x^{2}`          | $x^{2}$          |
# | Subíndice        | `x_{1}`          |  $x_{1}$           |
# | Raíz cuadrada    | `\sqrt{x}`       |  $\sqrt{x}$        |
# | Sumatoria        | `\sum_{i=1}^{n}` |  $\sum_{i=1}^{n}$  |
# | Integral         | `\int_{a}^{b}`   |  $\int_{a}^{b}$    |
# | Límite           | `\lim_{x \to 0}` |  $\lim_{x \to 0}$  |
# | Derivada parcial | `\partial x`     |  $\partial x$      |
# | Infinito         | `\infty`         |  $\infty$          |
# | Igualdad         | `=`              | =                  |

# %% [markdown]
# ### Tabla con almenos 30 simbolos
# |  Nº | Símbolo | Descripción       | Word (Ecuación)   | LaTeX             |
# | :-: | :------ | :---------------- | :---------------- | :---------------- |
# |  1  | ±       | Más/menos         | `\pm`             | `\pm`             |
# |  2  | ×       | Multiplicación    | `\times`          | `\times`          |
# |  3  | ÷       | División          | `\div`            | `\div`            |
# |  4  | ≤       | Menor o igual     | `\le`             | `\le`             |
# |  5  | ≥       | Mayor o igual     | `\ge`             | `\ge`             |
# |  6  | ≠       | Diferente         | `\neq`            | `\neq`            |
# |  7  | ∑       | Sumatoria         | `\sum`            | `\sum`            |
# |  8  | ∏       | Producto          | `\prod`           | `\prod`           |
# |  9  | ∫       | Integral          | `\int`            | `\int`            |
# |  10 | √       | Raíz cuadrada     | `\sqrt`           | `\sqrt{}`         |
# |  11 | ∞       | Infinito          | `\infty`          | `\infty`          |
# |  12 | ∂       | Derivada parcial  | `\partial`        | `\partial`        |
# |  13 | Δ       | Delta mayúscula   | `\Delta`          | `\Delta`          |
# |  14 | δ       | Delta minúscula   | `\delta`          | `\delta`          |
# |  15 | π       | Pi                | `\pi`             | `\pi`             |
# |  16 | θ       | Theta             | `\theta`          | `\theta`          |
# |  17 | α       | Alfa              | `\alpha`          | `\alpha`          |
# |  18 | β       | Beta              | `\beta`           | `\beta`           |
# |  19 | μ       | Mu                | `\mu`             | `\mu`             |
# |  20 | Ω       | Omega             | `\Omega`          | `\Omega`          |
# |  21 | ∈       | Pertenece a       | `\in`             | `\in`             |
# |  22 | ∉       | No pertenece      | `\notin`          | `\notin`          |
# |  23 | ∪       | Unión             | `\cup`            | `\cup`            |
# |  24 | ∩       | Intersección      | `\cap`            | `\cap`            |
# |  25 | ⊂       | Subconjunto       | `\subset`         | `\subset`         |
# |  26 | ⊆       | Subconjunto igual | `\subseteq`       | `\subseteq`       |
# |  27 | ⇒       | Implica           | `\Rightarrow`     | `\Rightarrow`     |
# |  28 | ⇔       | Si y solo si      | `\Leftrightarrow` | `\Leftrightarrow` |
# |  29 | ↔       | Doble flecha      | `\leftrightarrow` | `\leftrightarrow` |
# |  30 | ∇       | Nabla (gradiente) | `\nabla`          | `\nabla`          |
